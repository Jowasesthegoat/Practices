# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/Practices/blob/main/practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# End Statement
print("hello again guys i hope your having a wonderful day", end="*")

# next line statement
print ("The Following are my Favorite games/sports \n*soccer \n*fortnite \n*roblox \n*track \n*fc")

#Math
print("The additon of 45 and 65 is", 45+65)
# Out:
# hello again guys i hope your having a wonderful day*The Following are my Favorite games/sports
# *soccer
# *fortnite
# *roblox
# *track
# *fc
# The additon of 45 and 65 is 110
