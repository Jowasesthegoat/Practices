# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/Practices/blob/main/Practice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Math

print("The addition of 8 and 21 and then take away 9 is", 8+21-9)

print("The product of 7 and 17 then divide by 7 is", 7*17/7)

print("The Quotient of 112 and 4 then add 13 is",112/4+13)

print("The product of 7x35 take away five is",7*35-5)
# Out:
# The addition of 8 and 21 and then take away 9 is 20
# The product of 7 and 17 then divide by 7 is 17.0
# The Quotient of 112 and 4 then add 13 is 41.0
# The product of 7x35 take away five is 240
