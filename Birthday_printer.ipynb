# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/Practices/blob/main/Birthday_printer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adam's Birthday
Adam="12/15/2014"
print(f"Adam's birthday is {Adam}")

#Jacob's Birthday
Jacob="4/12/2015"
print(f"Jacob's birthday is {Jacob}")

#Amar's Birthday
Amar="6/27/2014"
print(f"Amar's birthday is {Amar}")

#Joshua's Birthday
Joshua="9/15/2014"
print(f"Joshua's birthday is {Joshua}")

#Hero's Birthday
Hero="3/27/2014"
print(f"Hero's Birthday is {Hero}")
# Out:
# Adam's birthday is 12/15/2014
# Jacob's birthday is 4/12/2015
# Amar's birthday is 6/27/2014
# Joshua's birthday is 9/15/2014
# Hero's Birthday is 3/27/2014
