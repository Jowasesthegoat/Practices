# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/Practices/blob/main/Practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Math + - / *

print("The addition of 8 and 21 is", 8+21)

print("The difference of 19 and 17 is", 19-17)

print("The Product of 9 and 7 is", 9*7)

print("The Quotient of 72 and 12 is", 72/12)

#End Statement

print("I wish you good luck at your game i hope you win", end=":)")

#Next line Statement

print("My Favorite subjects and foods are \n*Pizza \n*Fries \n*Math \n*PoundedYam \n*Gym")
# Out:
# The addition of 8 and 21 is 29
# The difference of 19 and 17 is 2
# The Product of 9 and 7 is 63
# The Quotient of 72 and 12 is 6.0
# I wish you good luck at your game i hope you win:)My Favorite subjects and foods are
# *Pizza
# *Fries
# *Math
# *PoundedYam
# *Gym
